# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # Tipuri de date de baza (primitive)

# %% [markdown]
# # 1. Int

# %%
x = 2
print(x)
# Out:
# 2

# %%
x
# Out:
# 2

# %%
type(x)
# Out:
# int

# %%
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# # 2. Float

# %%
x = 3.2
type(x)
# Out:
# float

# %% [markdown]
# # 3. String

# %%
x = 'hello'
type(x)
# Out:
# str

# %% [markdown]
# # 4. Bool

# %%
x = True
type(x)
# Out:
# bool

# %%
x = False
type(x)
# Out:
# bool

# %% [markdown]
# # Operatii - matematice

# %% [markdown]
# # 1. Intre float si int  functioneaza perfect

# %%
1 + 2.3
# Out:
# 3.3

# %% [markdown]
# # 2. Intre bool si  int/float - functioneaza

# %%
1 + True # Operatie matematica
# Out:
# 2

# %%
2 - False # Operatie matematica
# Out:
# 2

# %% [markdown]
# # Conversie la INT

# %%
int(23.32), int(True), int("32")
# Out:
# (23, 1, 32)

# %%
int("3232Y")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 int("3232Y")
#
# ValueError: invalid literal for int() with base 10: '3232Y'

# %% [markdown]
# # Conversie la Float

# %%
float(23), float(True), float("32.32")
# Out:
# (23.0, 1.0, 32.32)

# %%
float("3232Y")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 float("3232Y")
#
# ValueError: could not convert string to float: '3232Y'

# %% [markdown]
# # Conversie la String

# %%
str(23), str(True), str(32.32)
# Out:
# ('23', 'True', '32.32')

# %% [markdown]
# # Conversie la Bool - functioneaza de fiecare data

# %%
bool(20), bool(0), bool(-10)
# Out:
# (True, False, True)

# %%
bool(20.32), bool(0.0), bool(-10.321)
# Out:
# (True, False, True)

# %%
bool("ceva"), bool("0.0"), bool(""), bool(" ")
# Out:
# (True, True, False, True)
