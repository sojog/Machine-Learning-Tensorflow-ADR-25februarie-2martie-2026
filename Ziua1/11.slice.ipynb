# %%
# colectii: liste, tuple, range, string, dictionar

# %%
#         0    1     2     3    4
o_lista = [23, 121, 200, 300, 404]
len(o_lista)
# Out:
# 5

# %%
o_lista[4]
# Out:
# 404

# %%
o_lista[len(o_lista) - 1]
# Out:
# 404

# %%
o_lista[ - 1]
# Out:
# 404

# %%
o_lista = [23, 121, 200, 300, 404]
o_lista[0:2]
# Out:
# [23, 121]

# %%
o_lista = [23, 121, 200, 300, 404]
o_lista[-2:-1]
# Out:
# [300]

# %%
o_lista = [23, 121, 200, 300, 404]
o_lista[-2:]
# Out:
# [300, 404]

# %%
o_lista = [23, 121, 200, 300, 404]
o_lista[:2]
# Out:
# [23, 121]

# %%
o_lista = [23, 121, 200, 300, 404]
o_lista[:]
# Out:
# [23, 121, 200, 300, 404]

# %%
o_lista = [23, 121, 200, 300, 404]
o_lista[:5:2]
# Out:
# [23, 200, 404]

# %%
o_lista = [23, 121, 200, 300, 404]
o_lista[::-1]
# Out:
# [404, 300, 200, 121, 23]

# %%
text = "buna ziua"
text [0]
# Out:
# 'b'

# %%
text [-1]
# Out:
# 'a'

# %%
text [-4:]
# Out:
# 'ziua'

# %%
text [:4]
# Out:
# 'buna'

# %%
text = "buna ziua"
text[::-1]
# Out:
# 'auiz anub'

# %%
text = "buna ziua"
text.split()
# Out:
# ['buna', 'ziua']

# %%
text = "buna ziua"
text.split()[::-1]
# Out:
# ['ziua', 'buna']

# %%
text = "buna ziua"
" ".join(text.split()[::-1])
# Out:
# 'ziua buna'

# %%
text = "buna ziua"
"_".join(text.split()[::-1])
# Out:
# 'ziua_buna'

# %%
text = "buna ziua oameni frumosi"
"_".join(text.split()[::-1])
# Out:
# 'frumosi_oameni_ziua_buna'

# %% [markdown]
# # slice in numpy

# %%
import numpy as np

# %%
arr = np.random.randint(1, 100, 10)
arr
# Out:
# array([83, 53, 11, 61, 51, 64, 89, 73, 13, 14])

# %%
arr[2:6]
# Out:
# array([11, 61, 51, 64])

# %%
arr = np.random.randint(1, 100, (3, 2))
arr
# Out:
# array([[57,  4],
#        [66, 10],
#        [ 2, 59]])

# %%
arr[1]
# Out:
# array([66, 10])

# %%
arr[1][0]
# Out:
# np.int64(66)

# %%
arr[1, 0]
# Out:
# np.int64(66)

# %%
arr = np.random.randint(1, 100, (3, 2))
arr
# Out:
# array([[31, 79],
#        [19, 51],
#        [93, 25]])

# %%
arr[ : , 0 ]
# Out:
# array([31, 19, 93])

# %%
arr[ : , 1 ]
# Out:
# array([79, 51, 25])
