# %%
varsta = 18

if varsta >= 18:
    print("Major")
else:
    print("Minor")
# Out:
# Major

# %%
varsta = 18

if varsta >= 18:
    if varsta > 65:
        print("Pensionar")
    else:
        print("Major")
else:
    print("Minor")
# Out:
# Major

# %%
varsta = 18

if varsta >= 18:
    if varsta > 35:
        if varsta> 65:
            print("Pensionar")
        else:
            print("Adult")
    else:
        print("Tanar")
else:
    print("Minor")
# Out:
# Tanar

# %%
varsta = 18

if varsta < 18:
    print("Minor")
elif varsta < 35:
    print("Tanar")
elif varsta < 65:
    print("Adult")
else:
    print("Pensionar")
# Out:
# Tanar

# %%
varsta = 18

if varsta < 18:
    print("Minor")
elif varsta < 35:
    print("Tanar")
elif varsta < 65:
    print("Adult")
# Out:
# Tanar
