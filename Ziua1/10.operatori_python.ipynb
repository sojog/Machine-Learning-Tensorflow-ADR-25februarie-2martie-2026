# %%
# Operatii logice
print("True and True = ", True and True)
print("False and True = ", False and True)
print("True and False = ", True and False)
print("False and False = ", False and False)
# Out:
# True and True =  True
# False and True =  False
# True and False =  False
# False and False =  False

# %%
print("True or True = ", True or True)
print("False or True = ", False or True)
print("True or False = ", True or False)
print("False or False = ", False or False)
# Out:
# True or True =  True
# False or True =  True
# True or False =  True
# False or False =  False

# %%
print( "not True = ", not True)
print("not False = ", not False)
# Out:
# not True =  False
# not False =  True

# %% [markdown]
# # Operator Ternar

# %%
# 10 > 3 ? print("Adevarat") : print("Fals")

# %%
print("Adevarat") if 10 > 3 else print("Fals")
# Out:
# Adevarat

# %% [markdown]
# # Operator matematici speciali

# %%
10 / 2 # impartire normala -> intotdeauna float, chiar daca impartirea este FARA VIRGULA
# Out:
# 5.0

# %% [markdown]
# IMPARTIRE FARA REST

# %%
10 // 2
# Out:
# 5

# %%
11 // 2
# Out:
# 5

# %%
11 / 2
# Out:
# 5.5

# %% [markdown]
# RESTUL IMPARTIRII

# %%
11 % 2
# Out:
# 1

# %%
11 / 3
# Out:
# 3.6666666666666665

# %%
11 % 3
# Out:
# 2

# %% [markdown]
# RIDICARE LA PUTERE

# %%
10 ** 2
# Out:
# 100

# %%
10 ** 5
# Out:
# 100000
