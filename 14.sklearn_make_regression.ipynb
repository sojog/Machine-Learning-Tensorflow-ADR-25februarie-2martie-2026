# %% [markdown]
# # pip install scikit-learn

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
regr = make_regression()
type(regr), len(regr)
# Out:
# (tuple, 2)

# %%
x, y = make_regression()
type(x), type(y), x.shape, y.shape
# Out:
# (numpy.ndarray, numpy.ndarray, (100, 100), (100,))

# %%
x, y = make_regression(n_features=1, n_samples=5)
x.shape, y.shape
# Out:
# ((5, 1), (5,))

# %%
x, y
# Out:
# (array([[ 0.20778625],
#         [-0.07788237],
#         [-1.16547168],
#         [ 0.32978461],
#         [ 1.53371894]]),
#  array([  7.61834195,  -2.8555043 , -42.73122954,  12.09132923,
#          56.232766  ]))

# %%
plt.scatter(x, y)
plt.plot(x, y)

# %%
x, y = make_regression(n_features=1, n_samples=5)
plt.scatter(x, y, c="red");
plt.plot(x, y)

# %%
x, y = make_regression(n_features=1, n_samples=50)
plt.scatter(x, y, c="red");
plt.plot(x, y)

# %%
x, y = make_regression(n_features=1, n_samples=50, noise=5)
plt.scatter(x, y, c="red");
# plt.plot(x, y)

# %%
x, y = make_regression(n_features=1, n_samples=10, noise=5)
plt.scatter(x, y, c="red");

# %%
x, y = make_regression(n_features=1, n_samples=50, noise=5)
plt.scatter(x, y, c="red");

# %%
x_i = x 
y_i = y

# %%
plt.scatter(x_i, y_i, c="red");
plt.ylim(-20, 20)
plt.xlim(-10,10)
# Out:
# (-10.0, 10.0)

# %%
plt.scatter(x_i, y_i, c="red");
plt.ylim(-20, 20)
plt.xlim(-100,100)
# Out:
# (-100.0, 100.0)
