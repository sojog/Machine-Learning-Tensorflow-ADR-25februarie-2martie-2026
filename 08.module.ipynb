# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(49)
# Out:
# 7.0

# %%
math.floor(49.321)
# Out:
# 49

# %%
import random

# %%
random.randint(1, 100)
# Out:
# 43

# %%
random.randint(1, 100)
# Out:
# 99

# %%
random.random()
# Out:
# 0.8776285913712087

# %%
import time

# %%
time.sleep(2)

# %%
time.time()
# Out:
# 1772012268.039582

# %%
time.time()
# Out:
# 1772012272.4787068
