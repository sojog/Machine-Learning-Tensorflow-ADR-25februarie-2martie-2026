# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =  pd.read_csv("https://raw.githubusercontent.com/sojog/Machine-Learning-Tensorflow-ADR-25februarie-2martie-2026/refs/heads/main/Ziua2/boston_data.csv", index_col="ID")
df
# Out:
#      indus  chas    nox     rm   age     dis  rad  tax  ptratio  lstat  medv
# ID
# 1     2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3   4.98  24.0
# 2     7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8   9.14  21.6
# 4     2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7   2.94  33.4
# 5     2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7   5.33  36.2
# 7     7.87     0  0.524  6.012  66.6  5.5605    5  311     15.2  12.43  22.9
# ..     ...   ...    ...    ...   ...     ...  ...  ...      ...    ...   ...
# 500   9.69     0  0.585  5.569  73.5  2.3999    6  391     19.2  15.10  17.5
# 502  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0   9.67  22.4
# 503  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0   9.08  20.6
# 504  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0   5.64  23.9
# 506  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0   7.88  11.9
#
# [333 rows x 11 columns]

# %%
df.keys()
# Out:
# Index(['indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio',
#        'lstat', 'medv'],
#       dtype='object')

# %%
df.describe()
# Out:
#             indus        chas         nox          rm         age         dis  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean    11.293483    0.060060    0.557144    6.265619   68.226426    3.709934
# std      6.998123    0.237956    0.114955    0.703952   28.133344    1.981123
# min      0.740000    0.000000    0.385000    3.561000    6.000000    1.129600
# 25%      5.130000    0.000000    0.453000    5.884000   45.400000    2.122400
# 50%      9.900000    0.000000    0.538000    6.202000   76.700000    3.092300
# 75%     18.100000    0.000000    0.631000    6.595000   93.800000    5.116700
# max     27.740000    1.000000    0.871000    8.725000  100.000000   10.710300
#
#               rad         tax     ptratio       lstat        medv
# count  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     9.633634  409.279279   18.448048   12.515435   22.768769
# std      8.742174  170.841988    2.151821    7.067781    9.173468
# ...

# %%
df.head(2)
# Out:
#     indus  chas    nox     rm   age     dis  rad  tax  ptratio  lstat  medv
# ID
# 1    2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3   4.98  24.0
# 2    7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8   9.14  21.6

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
scaled_df_as_ndarray = scaler.fit_transform(df)
scaled_df_as_ndarray
# Out:
# array([[-1.28563081, -0.25278007, -0.16678732, ..., -1.46517068,
#         -1.06777158,  0.13441853],
#        [-0.60442483, -0.25278007, -0.76792805, ..., -0.30161579,
#         -0.47829937, -0.12759925],
#        [-1.30423517, -0.25278007, -0.86376208, ...,  0.11726397,
#         -1.35683968,  1.16065484],
#        ...,
#        [ 0.0910922 , -0.25278007,  0.13813914, ...,  1.18773447,
#         -0.48680137, -0.23677333],
#        [ 0.0910922 , -0.25278007,  0.13813914, ...,  1.18773447,
#         -0.97424954,  0.12350112],
#        [ 0.0910922 , -0.25278007,  0.13813914, ...,  1.18773447,
#         -0.65684143, -1.18658778]], shape=(333, 11))

# %%
scaled_df_as_ndarray.shape, df.shape
# Out:
# ((333, 11), (333, 11))

# %%
pd.DataFrame(scaled_df_as_ndarray)
# Out:
#            0        1         2         3         4         5        6   \
# 0   -1.285631 -0.25278 -0.166787  0.440154 -0.107736  0.192133 -0.98907
# 1   -0.604425 -0.25278 -0.767928  0.221060  0.379963  0.635528 -0.87451
# 2   -1.304235 -0.25278 -0.863762  1.041952 -0.798347  1.189127 -0.75995
# 3   -1.304235 -0.25278 -0.863762  1.253933 -0.499320  1.189127 -0.75995
# 4   -0.489936 -0.25278 -0.288758 -0.360821 -0.057898  0.935505 -0.53083
# ..        ...      ...       ...       ...       ...       ...      ...
# 328 -0.229475 -0.25278  0.242685 -0.991072  0.187731 -0.662253 -0.41627
# 329  0.091092 -0.25278  0.138139  0.465762  0.031098 -0.622468 -0.98907
# 330  0.091092 -0.25278  0.138139 -0.207170  0.301647 -0.719074 -0.98907
# 331  0.091092 -0.25278  0.138139  1.010653  0.810705 -0.779737 -0.98907
# 332  0.091092 -0.25278  0.138139 -0.335212  0.447600 -0.609123 -0.98907
#
#            7         8         9         10
# 0   -0.664062 -1.465171 -1.067772  0.134419
# ...

# %%
scaled_df = pd.DataFrame(scaled_df_as_ndarray, columns=df.columns)
scaled_df
# Out:
#         indus     chas       nox        rm       age       dis      rad  \
# 0   -1.285631 -0.25278 -0.166787  0.440154 -0.107736  0.192133 -0.98907
# 1   -0.604425 -0.25278 -0.767928  0.221060  0.379963  0.635528 -0.87451
# 2   -1.304235 -0.25278 -0.863762  1.041952 -0.798347  1.189127 -0.75995
# 3   -1.304235 -0.25278 -0.863762  1.253933 -0.499320  1.189127 -0.75995
# 4   -0.489936 -0.25278 -0.288758 -0.360821 -0.057898  0.935505 -0.53083
# ..        ...      ...       ...       ...       ...       ...      ...
# 328 -0.229475 -0.25278  0.242685 -0.991072  0.187731 -0.662253 -0.41627
# 329  0.091092 -0.25278  0.138139  0.465762  0.031098 -0.622468 -0.98907
# 330  0.091092 -0.25278  0.138139 -0.207170  0.301647 -0.719074 -0.98907
# 331  0.091092 -0.25278  0.138139  1.010653  0.810705 -0.779737 -0.98907
# 332  0.091092 -0.25278  0.138139 -0.335212  0.447600 -0.609123 -0.98907
#
#           tax   ptratio     lstat      medv
# 0   -0.664062 -1.465171 -1.067772  0.134419
# ...

# %%
# CRIM - per capita crime rate by town
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS - proportion of non-retail business acres per town.
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# NOX - nitric oxides concentration (parts per 10 million)
# RM - average number of rooms per dwelling
# AGE - proportion of owner-occupied units built prior to 1940
# DIS - weighted distances to five Boston employment centres
# RAD - index of accessibility to radial highways
# TAX - full-value property-tax rate per $10,000
# PTRATIO - pupil-teacher ratio by town
# B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# LSTAT - % lower status of the population
# MEDV - Median value of owner-occupied homes in $1000's

# %%
y = scaled_df[["medv"]] # iau o coloana ca DataFrame
y
# Out:
#          medv
# 0    0.134419
# 1   -0.127599
# 2    1.160655
# 3    1.466342
# 4    0.014327
# ..        ...
# 328 -0.575213
# 329 -0.040260
# 330 -0.236773
# 331  0.123501
# 332 -1.186588
#
# [333 rows x 1 columns]

# %%
x = scaled_df.drop("medv", axis=1)
x
# Out:
#         indus     chas       nox        rm       age       dis      rad  \
# 0   -1.285631 -0.25278 -0.166787  0.440154 -0.107736  0.192133 -0.98907
# 1   -0.604425 -0.25278 -0.767928  0.221060  0.379963  0.635528 -0.87451
# 2   -1.304235 -0.25278 -0.863762  1.041952 -0.798347  1.189127 -0.75995
# 3   -1.304235 -0.25278 -0.863762  1.253933 -0.499320  1.189127 -0.75995
# 4   -0.489936 -0.25278 -0.288758 -0.360821 -0.057898  0.935505 -0.53083
# ..        ...      ...       ...       ...       ...       ...      ...
# 328 -0.229475 -0.25278  0.242685 -0.991072  0.187731 -0.662253 -0.41627
# 329  0.091092 -0.25278  0.138139  0.465762  0.031098 -0.622468 -0.98907
# 330  0.091092 -0.25278  0.138139 -0.207170  0.301647 -0.719074 -0.98907
# 331  0.091092 -0.25278  0.138139  1.010653  0.810705 -0.779737 -0.98907
# 332  0.091092 -0.25278  0.138139 -0.335212  0.447600 -0.609123 -0.98907
#
#           tax   ptratio     lstat
# 0   -0.664062 -1.465171 -1.067772
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test =  train_test_split(x, y, test_size=0.2)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((266, 10), (67, 10), (266, 1), (67, 1))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor

# %%
linear_model = LinearRegression()
linear_model
# Out:
# LinearRegression()

# %%
knn_model = KNeighborsRegressor()
knn_model
# Out:
# KNeighborsRegressor()

# %%
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
print("Initial:", 0.6552138324562538)
linear_model.score(x_test, y_test)
# Out:
# Initial: 0.6552138324562538
# 0.6560381677734808

# %%
print("Initial:", 0.5313061807729447)
knn_model.score(x_test, y_test)
# Out:
# Initial: 0.5313061807729447
# 0.7907052644160426

# %%
print("Initial:","""{2: 0.5015058300662592,
 3: 0.6588559970977202,
 4: 0.6237380207466158,
 5: 0.5313061807729447,
 6: 0.48271005786712007,
 7: 0.42970692528260745,
 8: 0.4189154579372575,
 9: 0.37061823248216275,
 10: 0.32321057289753796}""" )
# Out:
# Initial: {2: 0.5015058300662592,
#  3: 0.6588559970977202,
#  4: 0.6237380207466158,
#  5: 0.5313061807729447,
#  6: 0.48271005786712007,
#  7: 0.42970692528260745,
#  8: 0.4189154579372575,
#  9: 0.37061823248216275,
#  10: 0.32321057289753796}

# %%
scores = {}
for k in range(2, 11): 
    inner_knn_model = KNeighborsRegressor(n_neighbors=k)
    inner_knn_model.fit(x_train, y_train)
    inner_score = inner_knn_model.score(x_test, y_test)
    scores[k] = inner_score

scores
# Out:
# {2: 0.7527746463748061,
#  3: 0.7496963213298703,
#  4: 0.7854276754475185,
#  5: 0.7907052644160426,
#  6: 0.7859183465064364,
#  7: 0.7698402589776383,
#  8: 0.761415003676043,
#  9: 0.7582998024236869,
#  10: 0.7760646785188484}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_model = GridSearchCV(estimator=KNeighborsRegressor(), param_grid={"n_neighbors":range(2, 11)})
grid_model
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': range(2, 11)})

# %%
grid_model.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': range(2, 11)})

# %%
grid_model.best_estimator_.score(x_test, y_test)
# Out:
# 0.7527746463748061

# %%
x_test
# Out:
#         indus      chas       nox        rm       age       dis       rad  \
# 34  -1.043774 -0.252780 -1.281947 -0.537234 -0.734270  1.824823 -0.759950
# 297  0.974084 -0.252780  1.357845  0.050337  0.550836 -0.468536  1.645813
# 259  0.974084 -0.252780  1.183601 -0.538657  0.942420 -0.974566  1.645813
# 151 -0.728931  3.956008 -0.436865  0.872652  0.337245 -0.221335 -0.187149
# 63  -1.128209 -0.252780 -0.593684  0.215369 -0.075698 -0.312229 -0.874510
# ..        ...       ...       ...       ...       ...       ...       ...
# 154 -0.728931 -0.252780 -0.463002  3.498937  0.525917 -0.412272 -0.187149
# 149  0.371589  3.956008 -0.062241 -0.537234 -0.435242 -0.302219 -0.530830
# 321  0.974084 -0.252780  0.225261 -0.513049 -0.534918 -0.281897  1.645813
# 41  -0.882059 -0.252780 -0.907323  0.706197 -0.883784  2.159075 -0.187149
# 53   0.219892 -0.252780 -1.046718 -0.178716 -0.798347  0.192385 -0.530830
#
#           tax   ptratio     lstat
# 34   0.350093  1.234277  0.323723
# ...
